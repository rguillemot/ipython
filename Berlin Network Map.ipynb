# %%
import pickle
output = open('all_stations.pkl', 'rb')
all_stations = pickle.load(output)
output.close()
output = open('stations_pos.pkl', 'rb')
stations_pos = pickle.load(output)
output.close()
output = open('shortpathdict.pkl', 'rb')
shortpathdict = pickle.load(output)
output.close()

# %%
# -*- coding: utf-8 -*- 
# %matplotlib qt

import matplotlib.pyplot as plt
import numpy as np
import math

from matplotlib import rcParams
rcParams['text.latex.unicode']=True

groupe = [u'Birkenstra\xdfe',u'Sch\xf6nhauser Allee',u'Gneisenaustra\xdfe',u'Sch\xf6nleinstra\xdfe']

def distance_groupe_station(station,groupe):
    return sum([len(shortpathdict[(station,s)]) for s in groupe])

def stddev_groupe_station(station,groupe):
    moyenne = sum([len(shortpathdict[(station,s)]) for s in groupe])
    return math.sqrt(sum([len(shortpathdict[(station,s)])**2 for s in groupe])-(moyenne**2)/len(groupe))

distances = {s:stddev_groupe_station(s,groupe) for s in stations_pos.keys()}

min_dist = min(distances.values())
max_dist = max(distances.values())


f, ax = plt.subplots(figsize=(12,6))
    
for k in stations_pos.keys():
    x = stations_pos[k][1]
    y = stations_pos[k][0]
    idx = min(round(distances[k]-min_dist),3)
    if idx == 0:
        ax.scatter(x,y,marker='o',c='red',facecolors='red', edgecolors='red',s=200)
    elif idx == 1:
        ax.scatter(x,y,marker='o',facecolors='green', edgecolors='green',s=150)
    elif idx == 2:
        ax.scatter(x,y,marker='o',facecolors='blue', edgecolors='blue',s=100)
    elif idx == 3:
        ax.scatter(x,y,marker='o',facecolors='black', edgecolors='black',s=50)
        
x_pos = [stations_pos[k][1] for k in stations_pos]
y_pos = [stations_pos[k][0] for k in stations_pos]
name = [ '%1.0f %s'%(min(round(distances[k]-min_dist),3),k) for k in stations_pos.keys()]

for k in groupe:
    x = stations_pos[k][1]
    y = stations_pos[k][0]
    ax.scatter(x,y,marker='o',facecolors='none', edgecolors='black',s=250)

ax.set_xlim(13.27, 13.49)
ax.set_ylim(52.46, 52.56)

af =  AnnoteFinder(x_pos,y_pos, name,ax)
connect('button_press_event', af)

plt.show()

# %%
import math
 
import pylab
import matplotlib
 
 
class AnnoteFinder:
   """
   callback for matplotlib to display an annotation when points are clicked on.  The
   point which is closest to the click and within xtol and ytol is identified.
     
   Register this function like this:
     
   scatter(xdata, ydata)
   af = AnnoteFinder(xdata, ydata, annotes)
   connect('button_press_event', af)
   """
 
   def __init__(self, xdata, ydata, annotes, axis=None, xtol=None, ytol=None):
     self.data = zip(xdata, ydata, annotes)
     if xtol is None:
       xtol = ((max(xdata) - min(xdata))/float(len(xdata)))/2
     if ytol is None:
       ytol = ((max(ydata) - min(ydata))/float(len(ydata)))/2
     self.xtol = xtol
     self.ytol = ytol
     if axis is None:
       self.axis = pylab.gca()
     else:
       self.axis= axis
     self.drawnAnnotations = {}
     self.links = []
 
   def distance(self, x1, x2, y1, y2):
     """
     return the distance between two points
     """
     return math.hypot(x1 - x2, y1 - y2)
 
   def __call__(self, event):
     if event.inaxes:
       clickX = event.xdata
       clickY = event.ydata
       if self.axis is None or self.axis==event.inaxes:
         annotes = []
         for x,y,a in self.data:
           if  clickX-self.xtol < x < clickX+self.xtol and  clickY-self.ytol < y < clickY+self.ytol :
             annotes.append((self.distance(x,clickX,y,clickY),x,y, a) )
         if annotes:
           annotes.sort()
           distance, x, y, annote = annotes[0]
           self.drawAnnote(event.inaxes, x, y, annote)
           for l in self.links:
             l.drawSpecificAnnote(annote)
 
   def drawAnnote(self, axis, x, y, annote):
     """
     Draw the annotation on the plot
     """
     if (x,y) in self.drawnAnnotations:
       markers = self.drawnAnnotations[(x,y)]
       for m in markers:
         m.set_visible(not m.get_visible())
       self.axis.figure.canvas.draw()
     else:
       t = axis.text(x,y, "%s"%(annote), size=17)
       m = axis.scatter([x],[y], marker='d', c='r', zorder=100)
       self.drawnAnnotations[(x,y)] =(t,m)
       self.axis.figure.canvas.draw()
 
   def drawSpecificAnnote(self, annote):
     annotesToDraw = [(x,y,a) for x,y,a in self.data if a==annote]
     for x,y,a in annotesToDraw:
       self.drawAnnote(self.axis, x, y, a)

# %%
x = range(10)
y = range(10)
annotes = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

fig = figure()
ax = fig.add_subplot(111)
ax.scatter(x,y)
af =  AnnoteFinder(x,y, annotes,ax)
connect('button_press_event', af)
# Out:
# 6

# %%
distances
# Out:
# {u'Adenauerplatz': 3.605551275463989,
#  u'Adlershof': 5.385164807134504,
#  u'Afrikanische Stra\xdfe': 9.0,
#  u'Ahrensfelde': 3.605551275463989,
#  u'Alexanderplatz': 3.605551275463989,
#  u'Alt-Mariendorf': 6.164414002968976,
#  u'Alt-Reinickendorf': 8.306623862918075,
#  u'Alt-Tegel': 9.0,
#  u'Alt-Tempelhof': 6.164414002968976,
#  u'Altglienicke': 5.385164807134504,
#  u'Altstadt Spandau': 9.643650760992955,
#  u'Amrumer Stra\xdfe': 9.643650760992955,
#  u'Anhalter Bahnhof': 4.47213595499958,
#  u'Attilastra\xdfe': 5.196152422706632,
#  u'Augsburger Stra\xdfe': 3.3166247903554,
#  u'Babelsberg': 4.47213595499958,
#  u'Baumschulenweg': 5.385164807134504,
#  u'Bayerischer Platz': 3.7416573867739413,
#  u'Bellevue': 3.0,
#  u'Bergfelde (b Bln)': 8.306623862918075,
#  u'Berliner Stra\xdfe': 3.3166247903554,
#  u'Bernau (b Bln)': 8.306623862918075,
#  u'Bernau-Friedenstal': 8.306623862918075,
#  u'Bernauer Stra\xdfe': 6.082762530298219,
#  u'Betriebsbf. Rummelsburg': 3.872983346207417,
#  u'Betriebsbf. Sch\xf6neweide': 5.385164807134504,
#  u'Beusselstra\xdfe': 9.643650760992955,
#  u'Biesdorf': 3.605551275463989,
#  u'Biesdorf-S\xfcd': 3.605551275463989,
#  u'Birkenstein': 3.605551275463989,
#  u'Birkenstra\xdfe': 9.539392014169456,
#  u'Birkenwerder': 8.306623862918075,
#  u'Bismarckstra\xdfe': 4.47213595499958,
#  u'Blankenburg': 8.306623862918075,
#  u'Blankenfelde (Kr Teltow-Fl\xe4ming)': 5.196152422706632,
#  u'Blaschkoallee': 7.14142842854285,
#  u'Blissestra\xdfe': 3.3166247903554,
#  u'Boddinstra\xdfe': 9.643650760992955,
#  u'Borgsdorf': 8.306623862918075,
#  u'Bornholmer Stra\xdfe': 8.306623862918075,
#  u'Borsigwerke': 9.0,
#  u'Botanischer Garten': 4.47213595499958,
#  u'Brandenburger Tor': 2.0,
#  u'Breitenbachplatz': 2.6457513110645907,
#  u'Britz-S\xfcd': 7.14142842854285,
